# %% [markdown]
# <a href="https://colab.research.google.com/github/kan1shk-07/the-begining/blob/main/pandas_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()

# %%
# !unzip archive.zip

# %%
import pandas as pd

df = pd.read_csv("anime.csv")
df.head()

# %%
display(df.info())

# %%
display(df.shape)

# %%
display(df.describe()

# %%
display(df.columns)

# %%
display(df.isnull().sum()

# %% [markdown]
# this checks if the columns have missing valuw and how many

# %%
type(df['anime_id'])

# %%
df['genre']

# %% [markdown]
# this give a idea of what the first and last elements of a column looks

# %% [markdown]
# to chech ti-he type of columns

# %%
df.at[4,"episodes"]

# %% [markdown]
# to check a value at a specific column with given line no.

# %%
df.loc[4]

# %% [markdown]
# to acces a row we use .loc method

# %%
df.sample(10)

# %% [markdown]
# ![Screenshot 2026-07-07 223216.png](data:image/png;base64,...)
